# %%
from groq import groq_chat

# %%
pr = "How do I solve the problem"

# %%
res = groq_chat(pr)
print(res)
# Out:
# 1. Identify the problem clearly.
# 2. Gather relevant information about the problem.
# 3. Break down the problem into smaller, manageable parts.
# 4. Determine the root cause of the problem.
# 5. Research possible solutions.
# 6. Evaluate the pros and cons of each potential solution.
# 7. Choose the most effective solution.
# 8. Create a plan to implement the chosen solution.
# 9. Take action to implement the plan.
# 10. Monitor and adjust the solution as needed.
